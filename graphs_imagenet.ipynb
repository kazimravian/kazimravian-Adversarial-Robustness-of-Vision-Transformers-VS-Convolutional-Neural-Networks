# %%
clean_acc = [0.82, 0.80, 0.82, 0.75, 0.80, 0.89, 0.85, 0.90]
legend = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']

adv_acc_fgsm = [0.09, 0.14, 0.9, 0.22, 0.35, 0.23, 0.40, 0.22]
adv_acc_pgd = [0.19, 0.35, 0.21, 0.38, 0.21, 0.34, 0.15, 0.13]
adv_acc_dfa = [0.15, 0.12, 0.21, 0.18, 0.20, 0.10, 0.22, 0.11]

# %%
import matplotlib.pyplot as plt

clean_acc = [0.82, 0.80, 0.82, 0.75, 0.80, 0.89, 0.85, 0.90]
legend = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']
adv_acc_fgsm = [0.09, 0.14, 0.9, 0.22, 0.35, 0.23, 0.40, 0.22]
adv_acc_pgd = [0.19, 0.35, 0.21, 0.38, 0.21, 0.34, 0.15, 0.13]
adv_acc_dfa = [0.15, 0.12, 0.21, 0.18, 0.20, 0.10, 0.22, 0.11]


plt.figure(figsize=(15, 5), dpi=300)

plt.subplot(311)
plt.scatter(clean_acc, adv_acc_fgsm, c=range(len(legend)), cmap='viridis', s=2000, marker='o')
for i, txt in enumerate(legend):
    plt.annotate(txt, (clean_acc[i], adv_acc_fgsm[i]), fontsize=14, ha='right', xytext=(5,5), textcoords='offset points')
plt.title("Clean acc vs Adversarial acc for FGSM", fontsize=20)
plt.xlabel('Clean accuracy', fontsize=16)
plt.ylabel('Adversarial accuracy', fontsize=16)

plt.subplot(312)
plt.scatter(clean_acc, adv_acc_pgd, c=range(len(legend)), cmap='viridis', s=2000, marker='o')
for i, txt in enumerate(legend):
    plt.annotate(txt, (clean_acc[i], adv_acc_pgd[i]), fontsize=14, ha='right', xytext=(5,5), textcoords='offset points')
plt.title("Clean acc vs Adversarial acc for PGD", fontsize=20)
plt.xlabel('Clean accuracy', fontsize=16)
plt.ylabel('Adversarial accuracy', fontsize=16)

plt.subplot(313)
plt.scatter(clean_acc, adv_acc_dfa, c=range(len(legend)), cmap='viridis', s=2000, marker='o')
for i, txt in enumerate(legend):
    plt.annotate(txt, (clean_acc[i], adv_acc_dfa[i]), fontsize=14, ha='right', xytext=(5,5), textcoords='offset points')
plt.title("Clean acc vs Adversarial acc for DFA", fontsize=20)
plt.xlabel('Clean accuracy', fontsize=16)
plt.ylabel('Adversarial accuracy', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# #Aversarial Robustness of Tatget Models (Vits and CNNs) against Adversarial Perturbation Methods FGSM, PGD, DFA

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']

# %%
# prompt: create comparison plot

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (7, 4))
plt.scatter(target_models, adv_acc_fgsm, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_acc_fgsm[i]))
plt.title("Adversarial robustness of target models against FGSM")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']
adv_robust_pgd = [2.46, 5.06, 0.00, 3.70, 18.75, 13.48, 0.00, 1.13]

# %%
plt.figure(figsize = (8, 4))
plt.scatter(target_models, adv_robust_pgd, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_robust_pgd[i]))
plt.title("Adversarial robustness of target models against PGD")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']
adv_robust_dfa = [16.04, 20.25, 15.66, 18.51, 34.56, 34.83, 34.83, 21.59]

# %%
plt.figure(figsize = (8, 4))
plt.scatter(target_models, adv_robust_dfa, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_robust_dfa[i]))
plt.title("Adversarial robustness of target models against DFA")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()
