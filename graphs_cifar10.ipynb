# %%
# !pip install adjustText

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

# Data
clean_acc = [0.77, 0.75, 0.82, 0.75, 0.85, 0.89, 0.77, 0.94]
legend = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']
adv_acc_fgsm = [0.07, 0.08, 0.03, 0.09, 0.15, 0.09, 0.12, 0.11]
adv_acc_pgd = [0.24, 0.39, 0.30, 0.45, 0.09, 0.31, 0.06, 0.09]
adv_acc_dfa = [0.19, 0.14, 0.12, 0.26, 0.12, 0.08, 0.25, 0.07]


# Plotting
plt.figure(figsize=(15, 5))

# FGSM
plt.subplot(131)
scatter = plt.scatter(clean_acc, adv_acc_fgsm, c=range(len(legend)), cmap='viridis', s=1000)
texts = [plt.text(clean_acc[i], adv_acc_fgsm[i], txt, fontsize=9, ha='right', va='bottom') for i, txt in enumerate(legend)]
adjust_text(texts)
plt.title("Clean acc vs Adversarial acc for FGSM")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')

# PGD
plt.subplot(132)
scatter = plt.scatter(clean_acc, adv_acc_pgd, c=range(len(legend)), cmap='viridis', s=1000)
texts = [plt.text(clean_acc[i], adv_acc_pgd[i], txt, fontsize=9, ha='right', va='bottom') for i, txt in enumerate(legend)]
adjust_text(texts)
plt.title("Clean acc vs Adversarial acc for PGD")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')

# DFA
plt.subplot(133)
scatter = plt.scatter(clean_acc, adv_acc_dfa, c=range(len(legend)), cmap='viridis', s=1000)
texts = [plt.text(clean_acc[i], adv_acc_dfa[i], txt, fontsize=9, ha='right', va='bottom') for i, txt in enumerate(legend)]
adjust_text(texts)
plt.title("Clean acc vs Adversarial acc for DFA")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

# Data
clean_acc = [0.77, 0.75, 0.82, 0.75, 0.85, 0.89, 0.77, 0.94]
adv_acc_fgsm = [0.07, 0.08, 0.03, 0.09, 0.15, 0.09, 0.12, 0.11]
adv_acc_pgd = [0.24, 0.39, 0.30, 0.45, 0.09, 0.31, 0.06, 0.09]
adv_acc_dfa = [0.19, 0.14, 0.12, 0.26, 0.12, 0.08, 0.25, 0.07]
legend = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']

# Plotting
plt.figure(figsize=(5, 15))

# FGSM
plt.subplot(311)
scatter = plt.scatter(clean_acc, adv_acc_fgsm, c=range(len(legend)), cmap='viridis', s=1000)
texts = [plt.text(clean_acc[i], adv_acc_fgsm[i], txt, fontsize=9, ha='right', va='bottom') for i, txt in enumerate(legend)]
adjust_text(texts)
plt.title("Clean acc vs Adversarial acc for FGSM")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')

# PGD
plt.subplot(312)
scatter = plt.scatter(clean_acc, adv_acc_pgd, c=range(len(legend)), cmap='viridis', s=1000)
texts = [plt.text(clean_acc[i], adv_acc_pgd[i], txt, fontsize=9, ha='right', va='bottom') for i, txt in enumerate(legend)]
adjust_text(texts)
plt.title("Clean acc vs Adversarial acc for PGD")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')

# DFA
plt.subplot(313)
scatter = plt.scatter(clean_acc, adv_acc_dfa, c=range(len(legend)), cmap='viridis', s=1000)
texts = [plt.text(clean_acc[i], adv_acc_dfa[i], txt, fontsize=9, ha='right', va='bottom') for i, txt in enumerate(legend)]
adjust_text(texts)
plt.title("Clean acc vs Adversarial acc for DFA")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Aversarial Robustness of Tatget Models (Vits and CNNs) against Adversarial Perturbation Methods FGSM, PGD, DFA

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']

# %%
# prompt: create comparison plot

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (7, 4))
plt.scatter(target_models, adv_acc_fgsm, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_acc_fgsm[i]))
plt.title("Adversarial robustness of target models against FGSM")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']

# %%
plt.figure(figsize = (7, 4))
plt.scatter(target_models, adv_acc_pgd, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_acc_pgd[i]))
plt.title("Adversarial robustness of target models against PGD")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']

# %%
plt.figure(figsize = (7, 4))
plt.scatter(target_models, adv_acc_dfa, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_acc_dfa[i]))
plt.title("Adversarial robustness of target models against DFA")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()
